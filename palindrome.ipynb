# %% [markdown]
# <a href="https://colab.research.google.com/github/Samiksha-Lambhade/Data_Science/blob/main/palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to check whether a number is a palindrome

num = input("Enter a number: ")

if num == num[::-1]:
    print(f"{num} is a palindrome.")
else:
    print(f"{num} is not a palindrome.")
# Out:
# Enter a number: -7
# -7 is not a palindrome.
