# %% [markdown]
# <a href="https://colab.research.google.com/github/Samiksha-Lambhade/Data_Science/blob/main/odd_even.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to check whether a number is odd or even

num = int(input("Enter a number: "))

if num % 2 == 0:
    print(f"{num} is an even number.")
else:
    print(f"{num} is an odd number.")
# Out:
# Enter a number: 5
# 5 is an odd number.
