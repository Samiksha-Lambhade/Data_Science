# %% [markdown]
# <a href="https://colab.research.google.com/github/Samiksha-Lambhade/Data_Science/blob/main/Factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to compute the factorial of a given number

num = int(input("Enter a number: "))

if num < 0:
    print("Factorial is not defined for negative numbers.")
else:
    factorial = 1
    for i in range(1, num + 1):
        factorial *= i
    print(f"The factorial of {num} is {factorial}")
# Out:
# Enter a number: 5
# The factorial of 5 is 120
